# %%
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import time
tfd = tfp.distributions
import tensorflow.python.ops.numpy_ops.np_config as np_config
np_config.enable_numpy_behavior()

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

#def logsumexp(x):
#  with tf.device('/gpu:0'):
#    c = tf.math.reduce_max(x)
#    return tf.math.exp(x - c + tf.reduce_logsumexp(x-c))

def proposal(currentState, sigma=1., nProps=100, gpu=True):
  dist       = tfd.Normal(loc=0.0,scale=sigma)
  dimensions = tf.size(currentState)
  center     = currentState + dist.sample([dimensions])
  props      = tf.repeat(center, repeats=[nProps], axis=0)
  if gpu:
    with tf.device('/gpu:0'):
      props     += dist.sample([nProps, dimensions])
  else:
    with tf.device('/cpu:0'):
      props     += dist.sample([nProps, dimensions])
  return props

def qpMCMC(propGpu,
               targetGpu,
               comps,
               nIts=1000,
               nProps=10000,
               dims=2,
               precision=1,
               targetAccept=0.65):
  states = tf.Variable(tf.zeros([nIts, dims]))
  accept = tf.Variable(tf.zeros([nIts])) 
  ranks  = tf.Variable(tf.zeros([nIts]))
  
  Acceptances = 0 # total acceptances within adaptation run (<= SampBound)
  SampBound = 5   # current total samples before adapting radius
  SampCount = 0   # number of samples collected (adapt when = SampBound)

  centers = tf.constant(name='centers', # get locations of mixture of gaussians
                        value=tf.cast(tf.range(0,comps*10,10),
                                      dtype=tf.float32),shape=[1,comps])
  locs    = tf.ones([comps,dims]) * centers.transpose()
  
  for i in range(1,nIts):
    props           = proposal(currentState=[tf.gather(states,i-1)],
                               nProps=nProps,
                               sigma=1/tf.math.sqrt(precision),
                               gpu=propGpu)
    currentAndProps = tf.concat(axis=0,values=[[tf.gather(states,i-1)],props])
    selectionProbs  = -target(currentAndProps, locations=locs,
                             gpu=targetGpu, components=comps)
    dist            = tfd.Gumbel(loc=0., scale=1.)
    with tf.device('/gpu:0'):
      selectionProbs -= dist.sample([nProps+1])
    ranks[i-1].assign(tf.cast(tf.reduce_sum(1*tf.math.less(selectionProbs,selectionProbs[0])),dtype=tf.float32))
    propIndex       = tf.argmin(selectionProbs)
    states[i,:].assign(tf.squeeze(tf.gather(currentAndProps,propIndex)))
    SampCount = SampCount + 1
    
    if propIndex != 0:
      accept[i].assign(1)
      Acceptances = Acceptances + 1    
    if i % 1000 == 0:
       tf.print("Iteration ", i, " complete.\n")
    if SampCount == SampBound: # adjust lambda at increasing intervals
      AcceptRatio = Acceptances / SampBound
      if AcceptRatio == 0:
        AdaptRatio  = 2
      else:
        AdaptRatio  = targetAccept / AcceptRatio
      if AdaptRatio > 2:
        AdaptRatio = 2
      if AdaptRatio < 0.5:
        AdaptRatio = 0.5
      precision *= AdaptRatio
      
      SampCount = 0
      SampBound = tf.math.ceil(tf.math.pow(tf.cast(SampBound,dtype=tf.float32),
                                           1.01))
      Acceptances = 0 
    if i > 100 and i % 1000 == 0:
      ess0 = tfp.mcmc.effective_sample_size(states[99:(i-1),:])
      print(ess0)
      if tf.math.minimum(x=ess0[0],y=ess0[1]) > 100. or i>2000000:
        print(tf.math.minimum(x=ess0[0],y=ess0[1]))
        return [i,ranks[1:(i-1)]]


def target(x, components, locations, gpu=True):

  bimix_gauss = tfd.MixtureSameFamily(
  mixture_distribution=tfd.Categorical(probs=tf.ones([components])),
  components_distribution=tfd.MultivariateNormalDiag(loc=locations))
  if gpu:
    with tf.device('/gpu:0'):
      return bimix_gauss.log_prob(x)
  else:
    with tf.device('/cpu:0'):
      return bimix_gauss.log_prob(x)

# def expoSearch(marks):
#   success  = False
#   m        = 1
#   grovIter = 0
#   lmbd     = 6/5
#   M        = tf.math.reduce_sum(1*(marks==1))
#   N        = tf.size(marks)
#   while (not success) and grovIter<(9*tf.math.sqrt(tf.cast(N,dtype=tf.float32))/4):
#     dist      = tfd.Categorical(probs=tf.ones([m])/m)
#     j         = dist.sample([1])
#     sqrtProbs = tf.ones([N])/tf.math.sqrt(tf.cast(N,dtype=tf.float32))
#     i         = 1
#     while i <= j:
#       sqrtProbs  = -marks*sqrtProbs + (1-marks)*sqrtProbs
#       sqrtProbs  = -sqrtProbs + 2*tf.reduce_mean(sqrtProbs)
#       i         += 1
#     dist = tfd.Categorical(probs=tf.math.pow(sqrtProbs,2))
#     draw = dist.sample([1]) + 1
#     grovIter += j
#     if draw <= M:
#       success = True
#     else:
#       m = tf.math.minimum(lmbd*m,tf.math.sqrt(tf.cast(N,dtype=tf.float32)))

#   return [grovIter,draw,success]

# def quantumMin(field, y):
#   done        = False
#   oracleCalls = 0
#   while not done:
#     marks        = 1*tf.math.less(field,field[y])
#     res          = expoSearch(marks)
#     oracleCalls += res[0]
#     if res[2]:
#       y = res[1]
#     else:
#       done = True
#   return([y,oracleCalls])
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Expo search test.

# %%
rng = tf.random.Generator.from_seed(seed=1, alg="philox")
nIts = 10000000
comps = 1000
d = 2

for nProps in [10000,5000,1000]:
  for k in tf.range(5):
      gpuOut = qpMCMC(propGpu=True, targetGpu=True, comps=comps,
              nIts=nIts,nProps=nProps,dims=d, targetAccept=0.50,
              precision=2.0*tf.math.sqrt(tf.cast(d,dtype=tf.float32)))

      with open('/content/drive/MyDrive/bbMCMC_output/qpStudy.txt', 'a') as f:
        print(nProps, gpuOut[0], file=f)
        f.close()

      if nProps == 10000:
        np.savetxt('/content/drive/MyDrive/bbMCMC_output/qpMCMC10KRanks'+tf.strings.as_string(k).numpy().decode()+'.txt',
                 gpuOut[1].numpy(),delimiter="\n\n")
      
      if nProps == 5000:
        np.savetxt('/content/drive/MyDrive/bbMCMC_output/qpMCMC5KRanks'+tf.strings.as_string(k).numpy().decode()+'.txt',
                 gpuOut[1].numpy(),delimiter="\n\n")
      
      if nProps == 1000:
        np.savetxt('/content/drive/MyDrive/bbMCMC_output/qpMCMC1KRanks'+tf.strings.as_string(k).numpy().decode()+'.txt',
                 gpuOut[1].numpy(),delimiter="\n\n")
# Out:
# Iteration  1000  complete.
#
# tf.Tensor([5.1562147 5.156122 ], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([14.31193   14.3115635], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([34.019897 34.019215], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([53.11577  53.114727], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([63.50887  63.503826], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([90.80033 90.79797], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([105.50243 105.49698], shape=(2,), dtype=float32)
# tf.Tensor(105.49698, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([9.551675 9.551849], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([25.432026 25.431696], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([42.6837  42.68397], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([64.69407 64.69492], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([92.130165 92.13    ], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([109.150894 109.15139 ], shape=(2,), dtype=float32)
# tf.Tensor(109.150894, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([17.586603 17.585936], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([35.32165  35.320526], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([61.945576 61.94381 ], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([81.235725 81.23508 ], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([111.790276 111.791306], shape=(2,), dtype=float32)
# tf.Tensor(111.790276, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([8.191135 8.191643], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([20.114044 20.11513 ], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([39.35476 39.35519], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([60.748257 60.749817], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([96.06772 96.0711 ], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([117.46297 117.46502], shape=(2,), dtype=float32)
# tf.Tensor(117.46297, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([6.6281743 6.6280537], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([21.716528 21.716003], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([35.376945 35.37559 ], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([58.66262 58.66188], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([74.286224 74.290054], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([109.76429 109.77038], shape=(2,), dtype=float32)
# tf.Tensor(109.76429, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([5.8213396 5.8212643], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([17.073893 17.07391 ], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([16.10018  16.100328], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([31.597113 31.59679 ], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([47.087555 47.087082], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([52.73651  52.735558], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([65.65528  65.652855], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([74.37246 74.36866], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([83.97339 83.96954], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([82.81095  82.806885], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([97.49116  97.486694], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([78.53414 78.53172], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([89.556854 89.55345 ], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([122.327225 122.3241  ], shape=(2,), dtype=float32)
# tf.Tensor(122.3241, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([4.615837 4.615893], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([8.428441 8.428428], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([20.269325 20.268814], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([31.618952 31.618147], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([32.14929 32.14861], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([43.229633 43.228382], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([51.86314  51.862053], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([49.348225 49.347565], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([58.216934 58.2162  ], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([62.05872 62.05808], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([69.30938  69.308044], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([80.13847 80.13666], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([92.56739 92.56513], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([106.035965 106.03389 ], shape=(2,), dtype=float32)
# tf.Tensor(106.03389, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([4.6101503 4.6102996], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([11.868055 11.868092], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([17.079666 17.079453], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([24.307886 24.30756 ], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([32.200413 32.19958 ], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([42.286774 42.2862  ], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([51.92624  51.925285], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([58.885044 58.884167], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([66.56639  66.565384], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([72.83648 72.83578], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([79.36164 79.36042], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([85.911125 85.909805], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([95.10467 95.10389], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([109.65663  109.655716], shape=(2,), dtype=float32)
# tf.Tensor(109.655716, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([4.825289 4.825243], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([11.340011 11.340142], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([21.10911  21.109056], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([14.748217 14.747815], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([21.971685 21.971407], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([34.551582 34.55134 ], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([43.6594   43.658867], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([54.998123 54.99817 ], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([66.12598 66.12537], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([76.128426 76.127335], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([85.58147 85.58097], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([95.38223 95.38143], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([107.319496 107.31879 ], shape=(2,), dtype=float32)
# tf.Tensor(107.31879, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([3.5481772 3.5481808], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([12.18062  12.180376], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([12.957438 12.957484], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([20.579939 20.579636], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([24.292206 24.292076], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([30.588339 30.588594], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([30.017145 30.017479], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([38.929   38.92922], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([47.07117  47.071342], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([58.640564 58.64028 ], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([65.921715 65.92117 ], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([72.94157 72.94058], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([81.64322 81.64166], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([90.958595 90.958305], shape=(2,), dtype=float32)
# Iteration  15000  complete.
#
# tf.Tensor([91.38734 91.38694], shape=(2,), dtype=float32)
# Iteration  16000  complete.
#
# tf.Tensor([93.28396  93.283424], shape=(2,), dtype=float32)
# Iteration  17000  complete.
#
# tf.Tensor([101.75466 101.75412], shape=(2,), dtype=float32)
# tf.Tensor(101.75412, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([2.7886372 2.788627 ], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([5.4854674 5.4853535], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([6.4570637 6.457022 ], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([7.343084  7.3431177], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([9.300812 9.300793], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([11.442284 11.442213], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([8.754873 8.754811], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([11.559886 11.559888], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([11.680868 11.680825], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([11.411385 11.411218], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([13.084076 13.083968], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([11.4412365 11.441087 ], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([9.766689 9.766589], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([8.95363  8.953533], shape=(2,), dtype=float32)
# Iteration  15000  complete.
#
# tf.Tensor([9.698563 9.698424], shape=(2,), dtype=float32)
# Iteration  16000  complete.
#
# tf.Tensor([10.615282 10.615174], shape=(2,), dtype=float32)
# Iteration  17000  complete.
#
# tf.Tensor([11.2845545 11.2844515], shape=(2,), dtype=float32)
# Iteration  18000  complete.
#
# tf.Tensor([11.872529 11.872413], shape=(2,), dtype=float32)
# Iteration  19000  complete.
#
# tf.Tensor([12.580693 12.580556], shape=(2,), dtype=float32)
# Iteration  20000  complete.
#
# tf.Tensor([12.713981 12.713869], shape=(2,), dtype=float32)
# Iteration  21000  complete.
#
# tf.Tensor([14.427712 14.427635], shape=(2,), dtype=float32)
# Iteration  22000  complete.
#
# tf.Tensor([15.063712 15.063589], shape=(2,), dtype=float32)
# Iteration  23000  complete.
#
# tf.Tensor([15.300308 15.300172], shape=(2,), dtype=float32)
# Iteration  24000  complete.
#
# tf.Tensor([15.930624 15.930492], shape=(2,), dtype=float32)
# Iteration  25000  complete.
#
# tf.Tensor([16.54888  16.548706], shape=(2,), dtype=float32)
# Iteration  26000  complete.
#
# tf.Tensor([17.193329 17.19312 ], shape=(2,), dtype=float32)
# Iteration  27000  complete.
#
# tf.Tensor([17.333279 17.333096], shape=(2,), dtype=float32)
# Iteration  28000  complete.
#
# tf.Tensor([17.180534 17.180397], shape=(2,), dtype=float32)
# Iteration  29000  complete.
#
# tf.Tensor([18.204609 18.204464], shape=(2,), dtype=float32)
# Iteration  30000  complete.
#
# tf.Tensor([19.610891 19.610695], shape=(2,), dtype=float32)
# Iteration  31000  complete.
#
# tf.Tensor([19.978582 19.978384], shape=(2,), dtype=float32)
# Iteration  32000  complete.
#
# tf.Tensor([20.968601 20.968388], shape=(2,), dtype=float32)
# Iteration  33000  complete.
#
# tf.Tensor([21.74981  21.749586], shape=(2,), dtype=float32)
# Iteration  34000  complete.
#
# tf.Tensor([23.446995 23.446829], shape=(2,), dtype=float32)
# Iteration  35000  complete.
#
# tf.Tensor([23.422758 23.422615], shape=(2,), dtype=float32)
# Iteration  36000  complete.
#
# tf.Tensor([24.04862  24.048416], shape=(2,), dtype=float32)
# Iteration  37000  complete.
#
# tf.Tensor([25.214085 25.213911], shape=(2,), dtype=float32)
# Iteration  38000  complete.
#
# tf.Tensor([26.157648 26.157463], shape=(2,), dtype=float32)
# Iteration  39000  complete.
#
# tf.Tensor([27.32734  27.327137], shape=(2,), dtype=float32)
# Iteration  40000  complete.
#
# tf.Tensor([28.250727 28.250542], shape=(2,), dtype=float32)
# Iteration  41000  complete.
#
# tf.Tensor([29.092604 29.09239 ], shape=(2,), dtype=float32)
# Iteration  42000  complete.
#
# tf.Tensor([29.856695 29.856487], shape=(2,), dtype=float32)
# Iteration  43000  complete.
#
# tf.Tensor([30.40906  30.408857], shape=(2,), dtype=float32)
# Iteration  44000  complete.
#
# tf.Tensor([30.19103  30.190807], shape=(2,), dtype=float32)
# Iteration  45000  complete.
#
# tf.Tensor([29.541636 29.541466], shape=(2,), dtype=float32)
# Iteration  46000  complete.
#
# tf.Tensor([31.17404 31.1738 ], shape=(2,), dtype=float32)
# Iteration  47000  complete.
#
# tf.Tensor([32.324776 32.32452 ], shape=(2,), dtype=float32)
# Iteration  48000  complete.
#
# tf.Tensor([31.613356 31.613173], shape=(2,), dtype=float32)
# Iteration  49000  complete.
#
# tf.Tensor([30.818037 30.817944], shape=(2,), dtype=float32)
# Iteration  50000  complete.
#
# tf.Tensor([29.745367 29.745325], shape=(2,), dtype=float32)
# Iteration  51000  complete.
#
# tf.Tensor([28.71429  28.714302], shape=(2,), dtype=float32)
# Iteration  52000  complete.
#
# tf.Tensor([27.669214 27.66925 ], shape=(2,), dtype=float32)
# Iteration  53000  complete.
#
# tf.Tensor([27.171936 27.172024], shape=(2,), dtype=float32)
# Iteration  54000  complete.
#
# tf.Tensor([26.96466  26.964815], shape=(2,), dtype=float32)
# Iteration  55000  complete.
#
# tf.Tensor([26.783096 26.7833  ], shape=(2,), dtype=float32)
# Iteration  56000  complete.
#
# tf.Tensor([27.069838 27.070019], shape=(2,), dtype=float32)
# Iteration  57000  complete.
#
# tf.Tensor([26.970873 26.97105 ], shape=(2,), dtype=float32)
# Iteration  58000  complete.
#
# tf.Tensor([26.721628 26.721811], shape=(2,), dtype=float32)
# Iteration  59000  complete.
#
# tf.Tensor([26.529734 26.52991 ], shape=(2,), dtype=float32)
# Iteration  60000  complete.
#
# tf.Tensor([26.134647 26.134853], shape=(2,), dtype=float32)
# Iteration  61000  complete.
#
# tf.Tensor([25.956192 25.956402], shape=(2,), dtype=float32)
# Iteration  62000  complete.
#
# tf.Tensor([26.454082 26.454332], shape=(2,), dtype=float32)
# Iteration  63000  complete.
#
# tf.Tensor([28.553864 28.554094], shape=(2,), dtype=float32)
# Iteration  64000  complete.
#
# tf.Tensor([29.275845 29.276077], shape=(2,), dtype=float32)
# Iteration  65000  complete.
#
# tf.Tensor([29.939686 29.939953], shape=(2,), dtype=float32)
# Iteration  66000  complete.
#
# tf.Tensor([31.00291  31.003092], shape=(2,), dtype=float32)
# Iteration  67000  complete.
#
# tf.Tensor([31.237894 31.23808 ], shape=(2,), dtype=float32)
# Iteration  68000  complete.
#
# tf.Tensor([31.375536 31.375717], shape=(2,), dtype=float32)
# Iteration  69000  complete.
#
# tf.Tensor([31.220898 31.22108 ], shape=(2,), dtype=float32)
# Iteration  70000  complete.
#
# tf.Tensor([31.61568  31.615862], shape=(2,), dtype=float32)
# Iteration  71000  complete.
#
# tf.Tensor([31.990864 31.991047], shape=(2,), dtype=float32)
# Iteration  72000  complete.
#
# tf.Tensor([33.150677 33.150837], shape=(2,), dtype=float32)
# Iteration  73000  complete.
#
# tf.Tensor([33.959946 33.960102], shape=(2,), dtype=float32)
# Iteration  74000  complete.
#
# tf.Tensor([34.053425 34.0536  ], shape=(2,), dtype=float32)
# Iteration  75000  complete.
#
# tf.Tensor([33.95987  33.960014], shape=(2,), dtype=float32)
# Iteration  76000  complete.
#
# tf.Tensor([35.428623 35.42878 ], shape=(2,), dtype=float32)
# Iteration  77000  complete.
#
# tf.Tensor([36.381332 36.381516], shape=(2,), dtype=float32)
# Iteration  78000  complete.
#
# tf.Tensor([36.927383 36.927555], shape=(2,), dtype=float32)
# Iteration  79000  complete.
#
# tf.Tensor([37.117275 37.117424], shape=(2,), dtype=float32)
# Iteration  80000  complete.
#
# tf.Tensor([37.36347 37.36363], shape=(2,), dtype=float32)
# Iteration  81000  complete.
#
# tf.Tensor([37.212456 37.21265 ], shape=(2,), dtype=float32)
# Iteration  82000  complete.
#
# tf.Tensor([36.930077 36.93028 ], shape=(2,), dtype=float32)
# Iteration  83000  complete.
#
# tf.Tensor([36.49067  36.490902], shape=(2,), dtype=float32)
# Iteration  84000  complete.
#
# tf.Tensor([36.541042 36.541256], shape=(2,), dtype=float32)
# Iteration  85000  complete.
#
# tf.Tensor([37.143883 37.14406 ], shape=(2,), dtype=float32)
# Iteration  86000  complete.
#
# tf.Tensor([38.599422 38.599606], shape=(2,), dtype=float32)
# Iteration  87000  complete.
#
# tf.Tensor([39.195442 39.195633], shape=(2,), dtype=float32)
# Iteration  88000  complete.
#
# tf.Tensor([39.45912  39.459312], shape=(2,), dtype=float32)
# Iteration  89000  complete.
#
# tf.Tensor([39.817978 39.818165], shape=(2,), dtype=float32)
# Iteration  90000  complete.
#
# tf.Tensor([40.294895 40.295105], shape=(2,), dtype=float32)
# Iteration  91000  complete.
#
# tf.Tensor([40.786186 40.78642 ], shape=(2,), dtype=float32)
# Iteration  92000  complete.
#
# tf.Tensor([40.83662  40.836796], shape=(2,), dtype=float32)
# Iteration  93000  complete.
#
# tf.Tensor([41.73945 41.73967], shape=(2,), dtype=float32)
# Iteration  94000  complete.
#
# tf.Tensor([41.776    41.776237], shape=(2,), dtype=float32)
# Iteration  95000  complete.
#
# tf.Tensor([42.47293  42.473167], shape=(2,), dtype=float32)
# Iteration  96000  complete.
#
# tf.Tensor([42.973442 42.97369 ], shape=(2,), dtype=float32)
# Iteration  97000  complete.
#
# tf.Tensor([43.530144 43.530415], shape=(2,), dtype=float32)
# Iteration  98000  complete.
#
# tf.Tensor([44.402573 44.40286 ], shape=(2,), dtype=float32)
# Iteration  99000  complete.
#
# tf.Tensor([45.037556 45.03787 ], shape=(2,), dtype=float32)
# Iteration  100000  complete.
#
# tf.Tensor([45.31266  45.312943], shape=(2,), dtype=float32)
# Iteration  101000  complete.
#
# tf.Tensor([45.611233 45.611515], shape=(2,), dtype=float32)
# Iteration  102000  complete.
#
# tf.Tensor([46.509277 46.509567], shape=(2,), dtype=float32)
# Iteration  103000  complete.
#
# tf.Tensor([47.527554 47.52783 ], shape=(2,), dtype=float32)
# Iteration  104000  complete.
#
# tf.Tensor([47.908417 47.908703], shape=(2,), dtype=float32)
# Iteration  105000  complete.
#
# tf.Tensor([49.324482 49.3248  ], shape=(2,), dtype=float32)
# Iteration  106000  complete.
#
# tf.Tensor([50.080326 50.08064 ], shape=(2,), dtype=float32)
# Iteration  107000  complete.
#
# tf.Tensor([50.915653 50.915985], shape=(2,), dtype=float32)
# Iteration  108000  complete.
#
# tf.Tensor([51.64838  51.648678], shape=(2,), dtype=float32)
# Iteration  109000  complete.
#
# tf.Tensor([52.181847 52.182133], shape=(2,), dtype=float32)
# Iteration  110000  complete.
#
# tf.Tensor([52.66984 52.67014], shape=(2,), dtype=float32)
# Iteration  111000  complete.
#
# tf.Tensor([53.591858 53.59218 ], shape=(2,), dtype=float32)
# Iteration  112000  complete.
#
# tf.Tensor([54.133144 54.133457], shape=(2,), dtype=float32)
# Iteration  113000  complete.
#
# tf.Tensor([54.18189  54.182186], shape=(2,), dtype=float32)
# Iteration  114000  complete.
#
# tf.Tensor([54.385357 54.385662], shape=(2,), dtype=float32)
# Iteration  115000  complete.
#
# tf.Tensor([56.224663 56.224964], shape=(2,), dtype=float32)
# Iteration  116000  complete.
#
# tf.Tensor([57.043922 57.044205], shape=(2,), dtype=float32)
# Iteration  117000  complete.
#
# tf.Tensor([56.40229 56.40257], shape=(2,), dtype=float32)
# Iteration  118000  complete.
#
# tf.Tensor([57.220043 57.22041 ], shape=(2,), dtype=float32)
# Iteration  119000  complete.
#
# tf.Tensor([57.978786 57.97916 ], shape=(2,), dtype=float32)
# Iteration  120000  complete.
#
# tf.Tensor([58.89071  58.891075], shape=(2,), dtype=float32)
# Iteration  121000  complete.
#
# tf.Tensor([59.461952 59.46234 ], shape=(2,), dtype=float32)
# Iteration  122000  complete.
#
# tf.Tensor([60.52992  60.530346], shape=(2,), dtype=float32)
# Iteration  123000  complete.
#
# tf.Tensor([61.034805 61.035183], shape=(2,), dtype=float32)
# Iteration  124000  complete.
#
# tf.Tensor([60.75265  60.753017], shape=(2,), dtype=float32)
# Iteration  125000  complete.
#
# tf.Tensor([60.187084 60.187405], shape=(2,), dtype=float32)
# Iteration  126000  complete.
#
# tf.Tensor([60.01679  60.017067], shape=(2,), dtype=float32)
# Iteration  127000  complete.
#
# tf.Tensor([61.743755 61.744034], shape=(2,), dtype=float32)
# Iteration  128000  complete.
#
# tf.Tensor([62.42427  62.424545], shape=(2,), dtype=float32)
# Iteration  129000  complete.
#
# tf.Tensor([63.073677 63.073967], shape=(2,), dtype=float32)
# Iteration  130000  complete.
#
# tf.Tensor([64.74756 64.74786], shape=(2,), dtype=float32)
# Iteration  131000  complete.
#
# tf.Tensor([65.39083 65.39117], shape=(2,), dtype=float32)
# Iteration  132000  complete.
#
# tf.Tensor([65.62394 65.62427], shape=(2,), dtype=float32)
# Iteration  133000  complete.
#
# tf.Tensor([65.03957 65.03992], shape=(2,), dtype=float32)
# Iteration  134000  complete.
#
# tf.Tensor([64.357086 64.357445], shape=(2,), dtype=float32)
# Iteration  135000  complete.
#
# tf.Tensor([67.0558  67.05612], shape=(2,), dtype=float32)
# Iteration  136000  complete.
#
# tf.Tensor([68.5941  68.59438], shape=(2,), dtype=float32)
# Iteration  137000  complete.
#
# tf.Tensor([68.80477 68.80508], shape=(2,), dtype=float32)
# Iteration  138000  complete.
#
# tf.Tensor([69.60698 69.60728], shape=(2,), dtype=float32)
# Iteration  139000  complete.
#
# tf.Tensor([69.69554 69.69585], shape=(2,), dtype=float32)
# Iteration  140000  complete.
#
# tf.Tensor([70.20396 70.20432], shape=(2,), dtype=float32)
# Iteration  141000  complete.
#
# tf.Tensor([71.06743 71.06782], shape=(2,), dtype=float32)
# Iteration  142000  complete.
#
# tf.Tensor([71.58601  71.586426], shape=(2,), dtype=float32)
# Iteration  143000  complete.
#
# tf.Tensor([72.32879 72.32923], shape=(2,), dtype=float32)
# Iteration  144000  complete.
#
# tf.Tensor([72.848885 72.84927 ], shape=(2,), dtype=float32)
# Iteration  145000  complete.
#
# tf.Tensor([72.86899  72.869385], shape=(2,), dtype=float32)
# Iteration  146000  complete.
#
# tf.Tensor([73.030876 73.03132 ], shape=(2,), dtype=float32)
# Iteration  147000  complete.
#
# tf.Tensor([73.983055 73.98345 ], shape=(2,), dtype=float32)
# Iteration  148000  complete.
#
# tf.Tensor([75.25005 75.25037], shape=(2,), dtype=float32)
# Iteration  149000  complete.
#
# tf.Tensor([76.77443 76.77473], shape=(2,), dtype=float32)
# Iteration  150000  complete.
#
# tf.Tensor([77.662415 77.66269 ], shape=(2,), dtype=float32)
# Iteration  151000  complete.
#
# tf.Tensor([77.69754  77.697784], shape=(2,), dtype=float32)
# Iteration  152000  complete.
#
# tf.Tensor([77.25419  77.254425], shape=(2,), dtype=float32)
# Iteration  153000  complete.
#
# tf.Tensor([76.96104 76.96133], shape=(2,), dtype=float32)
# Iteration  154000  complete.
#
# tf.Tensor([77.085   77.08535], shape=(2,), dtype=float32)
# Iteration  155000  complete.
#
# tf.Tensor([77.110886 77.11122 ], shape=(2,), dtype=float32)
# Iteration  156000  complete.
#
# tf.Tensor([77.022606 77.022964], shape=(2,), dtype=float32)
# Iteration  157000  complete.
#
# tf.Tensor([76.94573  76.946106], shape=(2,), dtype=float32)
# Iteration  158000  complete.
#
# tf.Tensor([78.08706 78.08738], shape=(2,), dtype=float32)
# Iteration  159000  complete.
#
# tf.Tensor([80.362335 80.362595], shape=(2,), dtype=float32)
# Iteration  160000  complete.
#
# tf.Tensor([80.96202  80.962204], shape=(2,), dtype=float32)
# Iteration  161000  complete.
#
# tf.Tensor([83.13274 83.13294], shape=(2,), dtype=float32)
# Iteration  162000  complete.
#
# tf.Tensor([83.97803  83.978195], shape=(2,), dtype=float32)
# Iteration  163000  complete.
#
# tf.Tensor([85.97822 85.97847], shape=(2,), dtype=float32)
# Iteration  164000  complete.
#
# tf.Tensor([86.96515  86.965324], shape=(2,), dtype=float32)
# Iteration  165000  complete.
#
# tf.Tensor([87.65175 87.65197], shape=(2,), dtype=float32)
# Iteration  166000  complete.
#
# tf.Tensor([88.52904 88.52924], shape=(2,), dtype=float32)
# Iteration  167000  complete.
#
# tf.Tensor([88.71591  88.716324], shape=(2,), dtype=float32)
# Iteration  168000  complete.
#
# tf.Tensor([88.431465 88.4319  ], shape=(2,), dtype=float32)
# Iteration  169000  complete.
#
# tf.Tensor([87.88521  87.885635], shape=(2,), dtype=float32)
# Iteration  170000  complete.
#
# tf.Tensor([85.97921  85.979675], shape=(2,), dtype=float32)
# Iteration  171000  complete.
#
# tf.Tensor([84.86233 84.8628 ], shape=(2,), dtype=float32)
# Iteration  172000  complete.
#
# tf.Tensor([84.95994 84.96037], shape=(2,), dtype=float32)
# Iteration  173000  complete.
#
# tf.Tensor([85.21148  85.211914], shape=(2,), dtype=float32)
# Iteration  174000  complete.
#
# tf.Tensor([84.894745 84.89521 ], shape=(2,), dtype=float32)
# Iteration  175000  complete.
#
# tf.Tensor([84.835335 84.83573 ], shape=(2,), dtype=float32)
# Iteration  176000  complete.
#
# tf.Tensor([86.96165 86.96213], shape=(2,), dtype=float32)
# Iteration  177000  complete.
#
# tf.Tensor([88.36566 88.36617], shape=(2,), dtype=float32)
# Iteration  178000  complete.
#
# tf.Tensor([88.879234 88.879745], shape=(2,), dtype=float32)
# Iteration  179000  complete.
#
# tf.Tensor([90.05759 90.05812], shape=(2,), dtype=float32)
# Iteration  180000  complete.
#
# tf.Tensor([92.91822 92.91878], shape=(2,), dtype=float32)
# Iteration  181000  complete.
#
# tf.Tensor([93.26127  93.261856], shape=(2,), dtype=float32)
# Iteration  182000  complete.
#
# tf.Tensor([92.722466 92.72307 ], shape=(2,), dtype=float32)
# Iteration  183000  complete.
#
# tf.Tensor([93.644516 93.645065], shape=(2,), dtype=float32)
# Iteration  184000  complete.
#
# tf.Tensor([96.21823  96.218605], shape=(2,), dtype=float32)
# Iteration  185000  complete.
#
# tf.Tensor([96.27475 96.27509], shape=(2,), dtype=float32)
# Iteration  186000  complete.
#
# tf.Tensor([95.732666 95.73301 ], shape=(2,), dtype=float32)
# Iteration  187000  complete.
#
# tf.Tensor([95.61036 95.61069], shape=(2,), dtype=float32)
# Iteration  188000  complete.
#
# tf.Tensor([95.57069 95.57103], shape=(2,), dtype=float32)
# Iteration  189000  complete.
#
# tf.Tensor([95.48691 95.48743], shape=(2,), dtype=float32)
# Iteration  190000  complete.
#
# tf.Tensor([95.465805 95.466324], shape=(2,), dtype=float32)
# Iteration  191000  complete.
#
# tf.Tensor([94.9902  94.99069], shape=(2,), dtype=float32)
# Iteration  192000  complete.
#
# tf.Tensor([96.10778 96.10827], shape=(2,), dtype=float32)
# Iteration  193000  complete.
#
# tf.Tensor([97.64293 97.64345], shape=(2,), dtype=float32)
# Iteration  194000  complete.
#
# tf.Tensor([98.34019 98.34066], shape=(2,), dtype=float32)
# Iteration  195000  complete.
#
# tf.Tensor([98.26206 98.26249], shape=(2,), dtype=float32)
# Iteration  196000  complete.
#
# tf.Tensor([97.456726 97.45715 ], shape=(2,), dtype=float32)
# Iteration  197000  complete.
#
# tf.Tensor([97.26836 97.2688 ], shape=(2,), dtype=float32)
# Iteration  198000  complete.
#
# tf.Tensor([97.27178 97.27225], shape=(2,), dtype=float32)
# Iteration  199000  complete.
#
# tf.Tensor([98.41901 98.41939], shape=(2,), dtype=float32)
# Iteration  200000  complete.
#
# tf.Tensor([99.656204 99.65662 ], shape=(2,), dtype=float32)
# Iteration  201000  complete.
#
# tf.Tensor([100.45771  100.458115], shape=(2,), dtype=float32)
# tf.Tensor(100.45771, shape=(), dtype=float32)
# Iteration  1000  complete.
#
# tf.Tensor([5.567439  5.5669756], shape=(2,), dtype=float32)
# Iteration  2000  complete.
#
# tf.Tensor([2.9731386 2.9731526], shape=(2,), dtype=float32)
# Iteration  3000  complete.
#
# tf.Tensor([6.208114  6.2081056], shape=(2,), dtype=float32)
# Iteration  4000  complete.
#
# tf.Tensor([5.461172 5.461208], shape=(2,), dtype=float32)
# Iteration  5000  complete.
#
# tf.Tensor([5.771396  5.7714477], shape=(2,), dtype=float32)
# Iteration  6000  complete.
#
# tf.Tensor([7.2823567 7.282419 ], shape=(2,), dtype=float32)
# Iteration  7000  complete.
#
# tf.Tensor([5.8547883 5.8548174], shape=(2,), dtype=float32)
# Iteration  8000  complete.
#
# tf.Tensor([9.518982 9.519093], shape=(2,), dtype=float32)
# Iteration  9000  complete.
#
# tf.Tensor([10.054791 10.05484 ], shape=(2,), dtype=float32)
# Iteration  10000  complete.
#
# tf.Tensor([11.85657  11.856611], shape=(2,), dtype=float32)
# Iteration  11000  complete.
#
# tf.Tensor([12.151815 12.151851], shape=(2,), dtype=float32)
# Iteration  12000  complete.
#
# tf.Tensor([11.834296 11.834351], shape=(2,), dtype=float32)
# Iteration  13000  complete.
#
# tf.Tensor([10.440981 10.441049], shape=(2,), dtype=float32)
# Iteration  14000  complete.
#
# tf.Tensor([10.577442 10.577515], shape=(2,), dtype=float32)
# Iteration  15000  complete.
#
# tf.Tensor([11.427056 11.427118], shape=(2,), dtype=float32)
# Iteration  16000  complete.
#
# tf.Tensor([12.640686 12.640832], shape=(2,), dtype=float32)
# Iteration  17000  complete.
#
# tf.Tensor([11.589621 11.589722], shape=(2,), dtype=float32)
# Iteration  18000  complete.
#
# tf.Tensor([10.218662 10.218773], shape=(2,), dtype=float32)
# Iteration  19000  complete.
#
# tf.Tensor([10.260994  10.2610445], shape=(2,), dtype=float32)
# Iteration  20000  complete.
#
# tf.Tensor([12.787241 12.78732 ], shape=(2,), dtype=float32)
# Iteration  21000  complete.
#
# tf.Tensor([13.243476 13.243546], shape=(2,), dtype=float32)
# Iteration  22000  complete.
#
# tf.Tensor([14.247306 14.24739 ], shape=(2,), dtype=float32)
# Iteration  23000  complete.
#
# tf.Tensor([15.081963 15.082052], shape=(2,), dtype=float32)
# Iteration  24000  complete.
#
# tf.Tensor([15.724791 15.724856], shape=(2,), dtype=float32)
# Iteration  25000  complete.
#
# tf.Tensor([15.413066 15.413129], shape=(2,), dtype=float32)
# Iteration  26000  complete.
#
# tf.Tensor([17.306644 17.306591], shape=(2,), dtype=float32)
# Iteration  27000  complete.
#
# tf.Tensor([18.825655 18.825634], shape=(2,), dtype=float32)
# Iteration  28000  complete.
#
# tf.Tensor([21.122719 21.122622], shape=(2,), dtype=float32)
# Iteration  29000  complete.
#
# tf.Tensor([22.936125 22.935953], shape=(2,), dtype=float32)
# Iteration  30000  complete.
#
# tf.Tensor([23.442192 23.442041], shape=(2,), dtype=float32)
# Iteration  31000  complete.
#
# tf.Tensor([22.920364 22.920328], shape=(2,), dtype=float32)
# Iteration  32000  complete.
#
# tf.Tensor([22.223434 22.223467], shape=(2,), dtype=float32)
# Iteration  33000  complete.
#
# tf.Tensor([22.4433   22.443348], shape=(2,), dtype=float32)
# Iteration  34000  complete.
#
# tf.Tensor([21.917881 21.917974], shape=(2,), dtype=float32)
# Iteration  35000  complete.
#
# tf.Tensor([21.20976  21.209877], shape=(2,), dtype=float32)
# Iteration  36000  complete.
#
# tf.Tensor([21.106504 21.106617], shape=(2,), dtype=float32)
# Iteration  37000  complete.
#
# tf.Tensor([22.604815 22.604927], shape=(2,), dtype=float32)
# Iteration  38000  complete.
#
# tf.Tensor([24.259777 24.259764], shape=(2,), dtype=float32)
# Iteration  39000  complete.
#
# tf.Tensor([24.28944  24.289482], shape=(2,), dtype=float32)
# Iteration  40000  complete.
#
# tf.Tensor([26.543789 26.543795], shape=(2,), dtype=float32)
# Iteration  41000  complete.
#
# tf.Tensor([27.983892 27.983873], shape=(2,), dtype=float32)
# Iteration  42000  complete.
#
# tf.Tensor([29.123987 29.124   ], shape=(2,), dtype=float32)
# Iteration  43000  complete.
#
# tf.Tensor([30.507124 30.507185], shape=(2,), dtype=float32)
# Iteration  44000  complete.
#
# tf.Tensor([31.199228 31.19928 ], shape=(2,), dtype=float32)
# Iteration  45000  complete.
#
# tf.Tensor([32.0813  32.08137], shape=(2,), dtype=float32)
# Iteration  46000  complete.
#
# tf.Tensor([33.02211  33.022144], shape=(2,), dtype=float32)
# Iteration  47000  complete.
#
# tf.Tensor([32.585747 32.585728], shape=(2,), dtype=float32)
# Iteration  48000  complete.
#
# tf.Tensor([31.343765 31.343647], shape=(2,), dtype=float32)
# Iteration  49000  complete.
#
# tf.Tensor([30.151917 30.1517  ], shape=(2,), dtype=float32)
# Iteration  50000  complete.
#
# tf.Tensor([30.187334 30.187141], shape=(2,), dtype=float32)
# Iteration  51000  complete.
#
# tf.Tensor([31.844112 31.84389 ], shape=(2,), dtype=float32)
# Iteration  52000  complete.
#
# tf.Tensor([32.51947 32.51924], shape=(2,), dtype=float32)
# Iteration  53000  complete.
#
# tf.Tensor([33.019722 33.019493], shape=(2,), dtype=float32)
# Iteration  54000  complete.
#
# tf.Tensor([32.884888 32.884663], shape=(2,), dtype=float32)
# Iteration  55000  complete.
#
# tf.Tensor([33.539555 33.539356], shape=(2,), dtype=float32)
# Iteration  56000  complete.
#
# tf.Tensor([33.145363 33.145233], shape=(2,), dtype=float32)
# Iteration  57000  complete.
#
# tf.Tensor([32.500576 32.500484], shape=(2,), dtype=float32)
# Iteration  58000  complete.
#
# tf.Tensor([31.628792 31.628742], shape=(2,), dtype=float32)
# Iteration  59000  complete.
#
# tf.Tensor([30.737974 30.737999], shape=(2,), dtype=float32)
# Iteration  60000  complete.
#
# tf.Tensor([30.133465 30.13359 ], shape=(2,), dtype=float32)
# Iteration  61000  complete.
#
# tf.Tensor([29.744558 29.744728], shape=(2,), dtype=float32)
# Iteration  62000  complete.
#
# tf.Tensor([29.373144 29.373375], shape=(2,), dtype=float32)
# Iteration  63000  complete.
#
# tf.Tensor([28.941446 28.941734], shape=(2,), dtype=float32)
# Iteration  64000  complete.
#
# tf.Tensor([28.758728 28.75907 ], shape=(2,), dtype=float32)
# Iteration  65000  complete.
#
# tf.Tensor([29.576998 29.577377], shape=(2,), dtype=float32)
# Iteration  66000  complete.
#
# tf.Tensor([31.048946 31.049274], shape=(2,), dtype=float32)
# Iteration  67000  complete.
#
# tf.Tensor([31.57544 31.57572], shape=(2,), dtype=float32)
# Iteration  68000  complete.
#
# tf.Tensor([31.122478 31.122704], shape=(2,), dtype=float32)
# Iteration  69000  complete.
#
# tf.Tensor([31.555588 31.555788], shape=(2,), dtype=float32)
# Iteration  70000  complete.
#
# tf.Tensor([33.343006 33.343243], shape=(2,), dtype=float32)
# Iteration  71000  complete.
#
# tf.Tensor([34.530308 34.530502], shape=(2,), dtype=float32)
# Iteration  72000  complete.
#
# tf.Tensor([34.445213 34.4454  ], shape=(2,), dtype=float32)
# Iteration  73000  complete.
#
# tf.Tensor([34.431595 34.43178 ], shape=(2,), dtype=float32)
# Iteration  74000  complete.
#
# tf.Tensor([34.605545 34.605717], shape=(2,), dtype=float32)
# Iteration  75000  complete.
#
# tf.Tensor([34.6264   34.626575], shape=(2,), dtype=float32)
# Iteration  76000  complete.
#
# tf.Tensor([34.616726 34.61689 ], shape=(2,), dtype=float32)
# Iteration  77000  complete.
#
# tf.Tensor([34.591534 34.59168 ], shape=(2,), dtype=float32)
# Iteration  78000  complete.
#
# tf.Tensor([36.516567 36.516766], shape=(2,), dtype=float32)
# Iteration  79000  complete.
#
# tf.Tensor([37.887543 37.887737], shape=(2,), dtype=float32)
# Iteration  80000  complete.
#
# tf.Tensor([37.819946 37.820126], shape=(2,), dtype=float32)
# Iteration  81000  complete.
#
# tf.Tensor([38.888195 38.888382], shape=(2,), dtype=float32)
# Iteration  82000  complete.
#
# tf.Tensor([40.63971 40.63989], shape=(2,), dtype=float32)
# Iteration  83000  complete.
#
# tf.Tensor([41.090458 41.09058 ], shape=(2,), dtype=float32)
# Iteration  84000  complete.
#
# tf.Tensor([42.43896  42.439095], shape=(2,), dtype=float32)
# Iteration  85000  complete.
#
# tf.Tensor([43.79562 43.79571], shape=(2,), dtype=float32)
# Iteration  86000  complete.
#
# tf.Tensor([43.865314 43.86541 ], shape=(2,), dtype=float32)
# Iteration  87000  complete.
#
# tf.Tensor([45.199924 45.200012], shape=(2,), dtype=float32)
# Iteration  88000  complete.
#
# tf.Tensor([45.790684 45.790783], shape=(2,), dtype=float32)
# Iteration  89000  complete.
#
# tf.Tensor([46.893753 46.89389 ], shape=(2,), dtype=float32)
# Iteration  90000  complete.
#
# tf.Tensor([47.20818  47.208286], shape=(2,), dtype=float32)
# Iteration  91000  complete.
#
# tf.Tensor([46.393852 46.393936], shape=(2,), dtype=float32)
# Iteration  92000  complete.
#
# tf.Tensor([45.49838  45.498463], shape=(2,), dtype=float32)
# Iteration  93000  complete.
#
# tf.Tensor([44.25721 44.25739], shape=(2,), dtype=float32)
# Iteration  94000  complete.
#
# tf.Tensor([42.851685 42.851936], shape=(2,), dtype=float32)
# Iteration  95000  complete.
#
# tf.Tensor([43.42607 43.42634], shape=(2,), dtype=float32)
# Iteration  96000  complete.
#
# tf.Tensor([43.778225 43.778572], shape=(2,), dtype=float32)
# Iteration  97000  complete.
#
# tf.Tensor([43.868557 43.868977], shape=(2,), dtype=float32)
# Iteration  98000  complete.
#
# tf.Tensor([44.099876 44.1004  ], shape=(2,), dtype=float32)
# Iteration  99000  complete.
#
# tf.Tensor([43.63515  43.635674], shape=(2,), dtype=float32)
# Iteration  100000  complete.
#
# tf.Tensor([43.085968 43.086452], shape=(2,), dtype=float32)
# Iteration  101000  complete.
#
# tf.Tensor([45.33499  45.335495], shape=(2,), dtype=float32)
# Iteration  102000  complete.
#
# tf.Tensor([46.213634 46.214108], shape=(2,), dtype=float32)
# Iteration  103000  complete.
#
# tf.Tensor([47.257835 47.2584  ], shape=(2,), dtype=float32)
# Iteration  104000  complete.
#
# tf.Tensor([48.08996 48.09056], shape=(2,), dtype=float32)
# Iteration  105000  complete.
#
# tf.Tensor([48.065895 48.066414], shape=(2,), dtype=float32)
# Iteration  106000  complete.
#
# tf.Tensor([47.025005 47.025528], shape=(2,), dtype=float32)
# Iteration  107000  complete.
#
# tf.Tensor([45.70962  45.710255], shape=(2,), dtype=float32)
# Iteration  108000  complete.
#
# tf.Tensor([35.53699 35.53771], shape=(2,), dtype=float32)
# Iteration  109000  complete.
#
# tf.Tensor([48.083374 48.083916], shape=(2,), dtype=float32)
# Iteration  110000  complete.
#
# tf.Tensor([48.67948  48.680023], shape=(2,), dtype=float32)
# Iteration  111000  complete.
#
# tf.Tensor([49.079445 49.079933], shape=(2,), dtype=float32)
# Iteration  112000  complete.
#
# tf.Tensor([49.26347 49.26393], shape=(2,), dtype=float32)
# Iteration  113000  complete.
#
# tf.Tensor([49.96342  49.963898], shape=(2,), dtype=float32)
# Iteration  114000  complete.
#
# tf.Tensor([50.96654 50.96704], shape=(2,), dtype=float32)
# Iteration  115000  complete.
#
# tf.Tensor([51.64092 51.64141], shape=(2,), dtype=float32)
# Iteration  116000  complete.
#
# tf.Tensor([52.69462  52.695114], shape=(2,), dtype=float32)
# Iteration  117000  complete.
#
# tf.Tensor([53.858715 53.85921 ], shape=(2,), dtype=float32)
# Iteration  118000  complete.
#
# tf.Tensor([54.296867 54.297375], shape=(2,), dtype=float32)
# Iteration  119000  complete.
#
# tf.Tensor([54.843792 54.844273], shape=(2,), dtype=float32)
# Iteration  120000  complete.
#
# tf.Tensor([55.38512  55.385605], shape=(2,), dtype=float32)
# Iteration  121000  complete.
#
# tf.Tensor([55.953907 55.95437 ], shape=(2,), dtype=float32)
# Iteration  122000  complete.
#
# tf.Tensor([56.43874  56.439217], shape=(2,), dtype=float32)
# Iteration  123000  complete.
#
# tf.Tensor([57.13278 57.13327], shape=(2,), dtype=float32)
# Iteration  124000  complete.
#
# tf.Tensor([57.909233 57.909718], shape=(2,), dtype=float32)
# Iteration  125000  complete.
#
# tf.Tensor([58.05337 58.05386], shape=(2,), dtype=float32)
# Iteration  126000  complete.
#
# tf.Tensor([57.72278  57.723236], shape=(2,), dtype=float32)
# Iteration  127000  complete.
#
# tf.Tensor([59.015133 59.015556], shape=(2,), dtype=float32)
# Iteration  128000  complete.
#
# tf.Tensor([60.08238 60.08277], shape=(2,), dtype=float32)
# Iteration  129000  complete.
#
# tf.Tensor([60.66422 60.6646 ], shape=(2,), dtype=float32)
# Iteration  130000  complete.
#
# tf.Tensor([60.882362 60.882797], shape=(2,), dtype=float32)
# Iteration  131000  complete.
#
# tf.Tensor([61.1289   61.129353], shape=(2,), dtype=float32)
# Iteration  132000  complete.
#
# tf.Tensor([61.888725 61.889194], shape=(2,), dtype=float32)
# Iteration  133000  complete.
#
# tf.Tensor([62.62617  62.626617], shape=(2,), dtype=float32)
# Iteration  134000  complete.
#
# tf.Tensor([63.597755 63.598156], shape=(2,), dtype=float32)
# Iteration  135000  complete.
#
# tf.Tensor([64.10296 64.10337], shape=(2,), dtype=float32)
# Iteration  136000  complete.
#
# tf.Tensor([63.945126 63.945507], shape=(2,), dtype=float32)
# Iteration  137000  complete.
#
# tf.Tensor([63.28719  63.287624], shape=(2,), dtype=float32)
# Iteration  138000  complete.
#
# tf.Tensor([63.074974 63.075417], shape=(2,), dtype=float32)
# Iteration  139000  complete.
#
# tf.Tensor([62.58967  62.590137], shape=(2,), dtype=float32)
# Iteration  140000  complete.
#
# tf.Tensor([62.330967 62.331444], shape=(2,), dtype=float32)
# Iteration  141000  complete.
#
# tf.Tensor([62.009094 62.0096  ], shape=(2,), dtype=float32)
# Iteration  142000  complete.
#
# tf.Tensor([61.771706 61.772217], shape=(2,), dtype=float32)
# Iteration  143000  complete.
#
# tf.Tensor([61.561207 61.561768], shape=(2,), dtype=float32)
# Iteration  144000  complete.
#
# tf.Tensor([61.028637 61.02924 ], shape=(2,), dtype=float32)
# Iteration  145000  complete.
#
# tf.Tensor([60.953056 60.95366 ], shape=(2,), dtype=float32)
# Iteration  146000  complete.
#
# tf.Tensor([61.413418 61.41398 ], shape=(2,), dtype=float32)
# Iteration  147000  complete.
#
# tf.Tensor([61.45392 61.4545 ], shape=(2,), dtype=float32)
# Iteration  148000  complete.
#
# tf.Tensor([61.87916 61.87978], shape=(2,), dtype=float32)
# Iteration  149000  complete.
#
# tf.Tensor([63.462597 63.46322 ], shape=(2,), dtype=float32)
# Iteration  150000  complete.
#
# tf.Tensor([63.968307 63.96892 ], shape=(2,), dtype=float32)
# Iteration  151000  complete.
#
# tf.Tensor([63.87365  63.874176], shape=(2,), dtype=float32)
# Iteration  152000  complete.
#
# tf.Tensor([63.6226   63.623096], shape=(2,), dtype=float32)
# Iteration  153000  complete.
#
# tf.Tensor([65.67475 65.67521], shape=(2,), dtype=float32)
# Iteration  154000  complete.
#
# tf.Tensor([66.7589  66.75935], shape=(2,), dtype=float32)
# Iteration  155000  complete.
#
# tf.Tensor([67.07673 67.07715], shape=(2,), dtype=float32)
# Iteration  156000  complete.
#
# tf.Tensor([67.16246  67.162895], shape=(2,), dtype=float32)
# Iteration  157000  complete.
#
# tf.Tensor([67.23854 67.23898], shape=(2,), dtype=float32)
# Iteration  158000  complete.
#
# tf.Tensor([67.72294 67.72338], shape=(2,), dtype=float32)
# Iteration  159000  complete.
#
# tf.Tensor([69.032005 69.032455], shape=(2,), dtype=float32)
# Iteration  160000  complete.
#
# tf.Tensor([69.821   69.82146], shape=(2,), dtype=float32)
# Iteration  161000  complete.
#
# tf.Tensor([69.648254 69.64867 ], shape=(2,), dtype=float32)
# Iteration  162000  complete.
#
# tf.Tensor([69.01461 69.015  ], shape=(2,), dtype=float32)
# Iteration  163000  complete.
#
# tf.Tensor([69.02816 69.02854], shape=(2,), dtype=float32)
# Iteration  164000  complete.
#
# tf.Tensor([68.8436  68.84398], shape=(2,), dtype=float32)
# Iteration  165000  complete.
#
# tf.Tensor([68.54447 68.54486], shape=(2,), dtype=float32)
# Iteration  166000  complete.
#
# tf.Tensor([69.79732 69.79777], shape=(2,), dtype=float32)
# Iteration  167000  complete.
#
# tf.Tensor([70.8509  70.85132], shape=(2,), dtype=float32)
# Iteration  168000  complete.
#
# tf.Tensor([71.53571  71.536125], shape=(2,), dtype=float32)
# Iteration  169000  complete.
#
# tf.Tensor([72.5544 72.5548], shape=(2,), dtype=float32)
# Iteration  170000  complete.
#
# tf.Tensor([74.29251 74.29292], shape=(2,), dtype=float32)
# Iteration  171000  complete.
#
# tf.Tensor([74.65929 74.65969], shape=(2,), dtype=float32)
# Iteration  172000  complete.
#
# tf.Tensor([75.31043  75.310905], shape=(2,), dtype=float32)
# Iteration  173000  complete.
#
# tf.Tensor([76.60451  76.604935], shape=(2,), dtype=float32)
# Iteration  174000  complete.
#
# tf.Tensor([77.30513 77.30548], shape=(2,), dtype=float32)
# Iteration  175000  complete.
#
# tf.Tensor([78.96944  78.969894], shape=(2,), dtype=float32)
# Iteration  176000  complete.
#
# tf.Tensor([80.30443 80.30481], shape=(2,), dtype=float32)
# Iteration  177000  complete.
#
# tf.Tensor([81.05587  81.056274], shape=(2,), dtype=float32)
# Iteration  178000  complete.
#
# tf.Tensor([81.4149  81.41527], shape=(2,), dtype=float32)
# Iteration  179000  complete.
#
# tf.Tensor([81.87022 81.87059], shape=(2,), dtype=float32)
# Iteration  180000  complete.
#
# tf.Tensor([82.565704 82.56609 ], shape=(2,), dtype=float32)
# Iteration  181000  complete.
#
# tf.Tensor([83.27852 83.27888], shape=(2,), dtype=float32)
# Iteration  182000  complete.
#
# tf.Tensor([83.49492  83.495285], shape=(2,), dtype=float32)
# Iteration  183000  complete.
#
# tf.Tensor([83.60097 83.60137], shape=(2,), dtype=float32)
# Iteration  184000  complete.
#
# tf.Tensor([83.46486 83.46529], shape=(2,), dtype=float32)
# Iteration  185000  complete.
#
# tf.Tensor([83.41061 83.41107], shape=(2,), dtype=float32)
# Iteration  186000  complete.
#
# tf.Tensor([83.147224 83.14768 ], shape=(2,), dtype=float32)
# Iteration  187000  complete.
#
# tf.Tensor([83.025024 83.025475], shape=(2,), dtype=float32)
# Iteration  188000  complete.
#
# tf.Tensor([82.822784 82.82327 ], shape=(2,), dtype=float32)
# Iteration  189000  complete.
#
# tf.Tensor([82.48964 82.49012], shape=(2,), dtype=float32)
# Iteration  190000  complete.
#
# tf.Tensor([83.2807  83.28118], shape=(2,), dtype=float32)
# Iteration  191000  complete.
#
# tf.Tensor([84.95375 84.95423], shape=(2,), dtype=float32)
# Iteration  192000  complete.
#
# tf.Tensor([85.43208  85.432556], shape=(2,), dtype=float32)
# Iteration  193000  complete.
#
# tf.Tensor([85.20133 85.20177], shape=(2,), dtype=float32)
# Iteration  194000  complete.
#
# tf.Tensor([84.45055  84.451004], shape=(2,), dtype=float32)
# Iteration  195000  complete.
#
# tf.Tensor([83.942635 83.94315 ], shape=(2,), dtype=float32)
# Iteration  196000  complete.
#
# tf.Tensor([82.96819  82.968704], shape=(2,), dtype=float32)
# Iteration  197000  complete.
#
# tf.Tensor([82.49622  82.496765], shape=(2,), dtype=float32)
# Iteration  198000  complete.
#
# tf.Tensor([82.74557 82.7461 ], shape=(2,), dtype=float32)
# Iteration  199000  complete.
#
# tf.Tensor([83.06963 83.07017], shape=(2,), dtype=float32)
# Iteration  200000  complete.
#
# tf.Tensor([83.38149 83.38206], shape=(2,), dtype=float32)
# Iteration  201000  complete.
#
# tf.Tensor([83.76325 83.76379], shape=(2,), dtype=float32)
# Iteration  202000  complete.
#
# tf.Tensor([84.102066 84.102646], shape=(2,), dtype=float32)
# Iteration  203000  complete.
#
# tf.Tensor([84.26826 84.26886], shape=(2,), dtype=float32)
# Iteration  204000  complete.
#
# tf.Tensor([84.27763  84.278244], shape=(2,), dtype=float32)
# Iteration  205000  complete.
#
# tf.Tensor([85.79485  85.795494], shape=(2,), dtype=float32)
# Iteration  206000  complete.
#
# tf.Tensor([87.15812 87.15876], shape=(2,), dtype=float32)
# Iteration  207000  complete.
#
# tf.Tensor([87.67341  87.673996], shape=(2,), dtype=float32)
# Iteration  208000  complete.
#
# tf.Tensor([88.14798 88.14858], shape=(2,), dtype=float32)
# Iteration  209000  complete.
#
# tf.Tensor([88.39807  88.398705], shape=(2,), dtype=float32)
# Iteration  210000  complete.
#
# tf.Tensor([89.391075 89.39166 ], shape=(2,), dtype=float32)
# Iteration  211000  complete.
#
# tf.Tensor([89.90112 89.90173], shape=(2,), dtype=float32)
# Iteration  212000  complete.
#
# tf.Tensor([90.425156 90.425766], shape=(2,), dtype=float32)
# Iteration  213000  complete.
#
# tf.Tensor([90.96142 90.96207], shape=(2,), dtype=float32)
# Iteration  214000  complete.
#
# tf.Tensor([91.371826 91.37246 ], shape=(2,), dtype=float32)
# Iteration  215000  complete.
#
# tf.Tensor([91.48695  91.487595], shape=(2,), dtype=float32)
# Iteration  216000  complete.
#
# tf.Tensor([91.53894  91.539566], shape=(2,), dtype=float32)
# Iteration  217000  complete.
#
# tf.Tensor([91.218765 91.21939 ], shape=(2,), dtype=float32)
# Iteration  218000  complete.
#
# tf.Tensor([91.77388 91.77452], shape=(2,), dtype=float32)
# Iteration  219000  complete.
#
# tf.Tensor([93.64798 93.64857], shape=(2,), dtype=float32)
# Iteration  220000  complete.
#
# tf.Tensor([94.50913 94.50972], shape=(2,), dtype=float32)
# Iteration  221000  complete.
#
# tf.Tensor([94.17756 94.17811], shape=(2,), dtype=float32)
# Iteration  222000  complete.
#
# tf.Tensor([93.883026 93.883575], shape=(2,), dtype=float32)
# Iteration  223000  complete.
#
# tf.Tensor([93.726685 93.72727 ], shape=(2,), dtype=float32)
# Iteration  224000  complete.
#
# tf.Tensor([94.1349  94.13548], shape=(2,), dtype=float32)
# Iteration  225000  complete.
#
# tf.Tensor([95.19176  95.192345], shape=(2,), dtype=float32)
# Iteration  226000  complete.
#
# tf.Tensor([95.76266 95.76327], shape=(2,), dtype=float32)
# Iteration  227000  complete.
#
# tf.Tensor([96.51696 96.51753], shape=(2,), dtype=float32)
# Iteration  228000  complete.
#
# tf.Tensor([97.04077  97.041374], shape=(2,), dtype=float32)
# Iteration  229000  complete.
#
# tf.Tensor([97.060875 97.06144 ], shape=(2,), dtype=float32)
# Iteration  230000  complete.
#
# tf.Tensor([97.133446 97.13401 ], shape=(2,), dtype=float32)
# Iteration  231000  complete.
#
# tf.Tensor([97.62519 97.62576], shape=(2,), dtype=float32)
# Iteration  232000  complete.
#
# ...
#
# tf.Tensor([30.701305 30.701536], shape=(2,), dtype=float32)
# Iteration  88000  complete.
#
# tf.Tensor([30.774275 30.774508], shape=(2,), dtype=float32)
# Iteration  89000  complete.
#
# tf.Tensor([30.70787 30.70808], shape=(2,), dtype=float32)
# Iteration  90000  complete.
#
# tf.Tensor([30.507029 30.507244], shape=(2,), dtype=float32)
# Iteration  91000  complete.
#
# tf.Tensor([31.167095 31.167313], shape=(2,), dtype=float32)
# Iteration  92000  complete.
#
# tf.Tensor([31.441637 31.44185 ], shape=(2,), dtype=float32)
# Iteration  93000  complete.
#
# tf.Tensor([31.977451 31.977654], shape=(2,), dtype=float32)
# Iteration  94000  complete.
#
# tf.Tensor([32.345375 32.345577], shape=(2,), dtype=float32)
# Iteration  95000  complete.
#
# tf.Tensor([32.97683  32.977055], shape=(2,), dtype=float32)
# Iteration  96000  complete.
#
# tf.Tensor([33.280315 33.280537], shape=(2,), dtype=float32)
# Iteration  97000  complete.
#
# tf.Tensor([33.56762  33.567833], shape=(2,), dtype=float32)
# Iteration  98000  complete.
#
# tf.Tensor([33.5396 33.5398], shape=(2,), dtype=float32)
# Iteration  99000  complete.
#
# tf.Tensor([33.488033 33.4882  ], shape=(2,), dtype=float32)
# Iteration  100000  complete.
#
# tf.Tensor([33.91967  33.919807], shape=(2,), dtype=float32)
# Iteration  101000  complete.
#
# tf.Tensor([35.36614  35.366352], shape=(2,), dtype=float32)
# Iteration  102000  complete.
#
# tf.Tensor([36.129078 36.129307], shape=(2,), dtype=float32)
# Iteration  103000  complete.
#
# tf.Tensor([36.408974 36.409225], shape=(2,), dtype=float32)
# Iteration  104000  complete.
#
# tf.Tensor([37.3176   37.317833], shape=(2,), dtype=float32)
# Iteration  105000  complete.
#
# tf.Tensor([39.041306 39.04156 ], shape=(2,), dtype=float32)
# Iteration  106000  complete.
#
# tf.Tensor([39.696922 39.69717 ], shape=(2,), dtype=float32)
# Iteration  107000  complete.
#
# tf.Tensor([40.030346 40.030613], shape=(2,), dtype=float32)
# Iteration  108000  complete.
#
# tf.Tensor([40.882008 40.882294], shape=(2,), dtype=float32)
# Iteration  109000  complete.
#
# tf.Tensor([41.53979 41.54005], shape=(2,), dtype=float32)
# Iteration  110000  complete.
#
# tf.Tensor([42.323208 42.3235  ], shape=(2,), dtype=float32)
# Iteration  111000  complete.
#
# tf.Tensor([43.34437 43.34465], shape=(2,), dtype=float32)
# Iteration  112000  complete.
#
# tf.Tensor([43.69724 43.69747], shape=(2,), dtype=float32)
# Iteration  113000  complete.
#
# tf.Tensor([43.362232 43.36245 ], shape=(2,), dtype=float32)
# Iteration  114000  complete.
#
# tf.Tensor([43.40673  43.406963], shape=(2,), dtype=float32)
# Iteration  115000  complete.
#
# tf.Tensor([43.87516 43.87539], shape=(2,), dtype=float32)
# Iteration  116000  complete.
#
# tf.Tensor([45.308514 45.308765], shape=(2,), dtype=float32)
# Iteration  117000  complete.
#
# tf.Tensor([45.78657  45.786804], shape=(2,), dtype=float32)
# Iteration  118000  complete.
#
# tf.Tensor([46.51339  46.513634], shape=(2,), dtype=float32)
# Iteration  119000  complete.
#
# tf.Tensor([47.19541 47.19563], shape=(2,), dtype=float32)
# Iteration  120000  complete.
#
# tf.Tensor([47.579445 47.57966 ], shape=(2,), dtype=float32)
# Iteration  121000  complete.
#
# tf.Tensor([47.971195 47.971413], shape=(2,), dtype=float32)
# Iteration  122000  complete.
#
# tf.Tensor([48.524387 48.524616], shape=(2,), dtype=float32)
# Iteration  123000  complete.
#
# tf.Tensor([49.97272 49.9729 ], shape=(2,), dtype=float32)
# Iteration  124000  complete.
#
# tf.Tensor([50.50801  50.508183], shape=(2,), dtype=float32)
# Iteration  125000  complete.
#
# tf.Tensor([50.58078 50.58096], shape=(2,), dtype=float32)
# Iteration  126000  complete.
#
# tf.Tensor([50.310917 50.311085], shape=(2,), dtype=float32)
# Iteration  127000  complete.
#
# tf.Tensor([50.4185  50.41872], shape=(2,), dtype=float32)
# Iteration  128000  complete.
#
# tf.Tensor([51.89051  51.890682], shape=(2,), dtype=float32)
# Iteration  129000  complete.
#
# tf.Tensor([52.71949  52.719627], shape=(2,), dtype=float32)
# Iteration  130000  complete.
#
# tf.Tensor([53.271862 53.272007], shape=(2,), dtype=float32)
# Iteration  131000  complete.
#
# tf.Tensor([53.07453 53.07467], shape=(2,), dtype=float32)
# Iteration  132000  complete.
#
# tf.Tensor([52.783726 52.783882], shape=(2,), dtype=float32)
# Iteration  133000  complete.
#
# tf.Tensor([52.99859 52.99874], shape=(2,), dtype=float32)
# Iteration  134000  complete.
#
# tf.Tensor([52.934437 52.934612], shape=(2,), dtype=float32)
# Iteration  135000  complete.
#
# tf.Tensor([55.17323 55.17339], shape=(2,), dtype=float32)
# Iteration  136000  complete.
#
# tf.Tensor([56.03608  56.036205], shape=(2,), dtype=float32)
# Iteration  137000  complete.
#
# tf.Tensor([56.318104 56.318233], shape=(2,), dtype=float32)
# Iteration  138000  complete.
#
# tf.Tensor([56.447052 56.447216], shape=(2,), dtype=float32)
# Iteration  139000  complete.
#
# tf.Tensor([56.196445 56.196648], shape=(2,), dtype=float32)
# Iteration  140000  complete.
#
# tf.Tensor([56.122124 56.122337], shape=(2,), dtype=float32)
# Iteration  141000  complete.
#
# tf.Tensor([55.503716 55.50395 ], shape=(2,), dtype=float32)
# Iteration  142000  complete.
#
# tf.Tensor([54.470585 54.470867], shape=(2,), dtype=float32)
# Iteration  143000  complete.
#
# tf.Tensor([53.70586 53.70618], shape=(2,), dtype=float32)
# Iteration  144000  complete.
#
# tf.Tensor([52.903362 52.90371 ], shape=(2,), dtype=float32)
# Iteration  145000  complete.
#
# tf.Tensor([51.93758 51.93798], shape=(2,), dtype=float32)
# Iteration  146000  complete.
#
# tf.Tensor([51.604427 51.60484 ], shape=(2,), dtype=float32)
# Iteration  147000  complete.
#
# tf.Tensor([52.785976 52.78635 ], shape=(2,), dtype=float32)
# Iteration  148000  complete.
#
# tf.Tensor([53.08636 53.08674], shape=(2,), dtype=float32)
# Iteration  149000  complete.
#
# tf.Tensor([53.34041  53.340782], shape=(2,), dtype=float32)
# Iteration  150000  complete.
#
# tf.Tensor([53.625694 53.626064], shape=(2,), dtype=float32)
# Iteration  151000  complete.
#
# tf.Tensor([53.883625 53.884007], shape=(2,), dtype=float32)
# Iteration  152000  complete.
#
# tf.Tensor([53.647606 53.64798 ], shape=(2,), dtype=float32)
# Iteration  153000  complete.
#
# tf.Tensor([53.24309 53.24348], shape=(2,), dtype=float32)
# Iteration  154000  complete.
#
# tf.Tensor([53.728523 53.728924], shape=(2,), dtype=float32)
# Iteration  155000  complete.
#
# tf.Tensor([53.778576 53.77897 ], shape=(2,), dtype=float32)
# Iteration  156000  complete.
#
# tf.Tensor([53.612488 53.612877], shape=(2,), dtype=float32)
# Iteration  157000  complete.
#
# tf.Tensor([53.552647 53.55302 ], shape=(2,), dtype=float32)
# Iteration  158000  complete.
#
# tf.Tensor([53.48959  53.489956], shape=(2,), dtype=float32)
# Iteration  159000  complete.
#
# tf.Tensor([53.431435 53.43178 ], shape=(2,), dtype=float32)
# Iteration  160000  complete.
#
# tf.Tensor([53.03436  53.034706], shape=(2,), dtype=float32)
# Iteration  161000  complete.
#
# tf.Tensor([53.008007 53.008324], shape=(2,), dtype=float32)
# Iteration  162000  complete.
#
# tf.Tensor([52.995796 52.996124], shape=(2,), dtype=float32)
# Iteration  163000  complete.
#
# tf.Tensor([53.162308 53.162632], shape=(2,), dtype=float32)
# Iteration  164000  complete.
#
# tf.Tensor([54.181896 54.182262], shape=(2,), dtype=float32)
# Iteration  165000  complete.
#
# tf.Tensor([55.278263 55.27864 ], shape=(2,), dtype=float32)
# Iteration  166000  complete.
#
# tf.Tensor([55.758705 55.75909 ], shape=(2,), dtype=float32)
# Iteration  167000  complete.
#
# tf.Tensor([56.21207  56.212467], shape=(2,), dtype=float32)
# Iteration  168000  complete.
#
# tf.Tensor([56.34699 56.34739], shape=(2,), dtype=float32)
# Iteration  169000  complete.
#
# tf.Tensor([56.66157  56.661953], shape=(2,), dtype=float32)
# Iteration  170000  complete.
#
# tf.Tensor([56.916904 56.917286], shape=(2,), dtype=float32)
# Iteration  171000  complete.
#
# tf.Tensor([57.330524 57.330906], shape=(2,), dtype=float32)
# Iteration  172000  complete.
#
# tf.Tensor([57.493515 57.493893], shape=(2,), dtype=float32)
# Iteration  173000  complete.
#
# tf.Tensor([57.59348 57.59384], shape=(2,), dtype=float32)
# Iteration  174000  complete.
#
# tf.Tensor([58.47967  58.480057], shape=(2,), dtype=float32)
# Iteration  175000  complete.
#
# tf.Tensor([59.302303 59.302723], shape=(2,), dtype=float32)
# Iteration  176000  complete.
#
# tf.Tensor([59.968266 59.968685], shape=(2,), dtype=float32)
# Iteration  177000  complete.
#
# tf.Tensor([60.68781  60.688225], shape=(2,), dtype=float32)
# Iteration  178000  complete.
#
# tf.Tensor([61.171856 61.17226 ], shape=(2,), dtype=float32)
# Iteration  179000  complete.
#
# tf.Tensor([61.879204 61.879623], shape=(2,), dtype=float32)
# Iteration  180000  complete.
#
# tf.Tensor([62.449196 62.449604], shape=(2,), dtype=float32)
# Iteration  181000  complete.
#
# tf.Tensor([62.858337 62.858757], shape=(2,), dtype=float32)
# Iteration  182000  complete.
#
# tf.Tensor([63.20184 63.20222], shape=(2,), dtype=float32)
# Iteration  183000  complete.
#
# tf.Tensor([62.978138 62.978508], shape=(2,), dtype=float32)
# Iteration  184000  complete.
#
# tf.Tensor([63.019485 63.019814], shape=(2,), dtype=float32)
# Iteration  185000  complete.
#
# tf.Tensor([64.55339 64.5538 ], shape=(2,), dtype=float32)
# Iteration  186000  complete.
#
# tf.Tensor([65.51929 65.5197 ], shape=(2,), dtype=float32)
# Iteration  187000  complete.
#
# tf.Tensor([65.91984 65.92024], shape=(2,), dtype=float32)
# Iteration  188000  complete.
#
# tf.Tensor([66.43918 66.43959], shape=(2,), dtype=float32)
# Iteration  189000  complete.
#
# tf.Tensor([67.23784 67.23825], shape=(2,), dtype=float32)
# Iteration  190000  complete.
#
# tf.Tensor([67.52428 67.52468], shape=(2,), dtype=float32)
# Iteration  191000  complete.
#
# tf.Tensor([67.86376 67.86419], shape=(2,), dtype=float32)
# Iteration  192000  complete.
#
# tf.Tensor([68.161804 68.162224], shape=(2,), dtype=float32)
# Iteration  193000  complete.
#
# tf.Tensor([69.68046 69.68088], shape=(2,), dtype=float32)
# Iteration  194000  complete.
#
# tf.Tensor([70.39097 70.39141], shape=(2,), dtype=float32)
# Iteration  195000  complete.
#
# tf.Tensor([70.71263 70.71307], shape=(2,), dtype=float32)
# Iteration  196000  complete.
#
# tf.Tensor([71.36641 71.36687], shape=(2,), dtype=float32)
# Iteration  197000  complete.
#
# tf.Tensor([71.843834 71.84428 ], shape=(2,), dtype=float32)
# Iteration  198000  complete.
#
# tf.Tensor([72.12313 72.1236 ], shape=(2,), dtype=float32)
# Iteration  199000  complete.
#
# tf.Tensor([72.52172  72.522156], shape=(2,), dtype=float32)
# Iteration  200000  complete.
#
# tf.Tensor([73.44999 73.45043], shape=(2,), dtype=float32)
# Iteration  201000  complete.
#
# tf.Tensor([73.79135 73.79181], shape=(2,), dtype=float32)
# Iteration  202000  complete.
#
# tf.Tensor([74.254364 74.25483 ], shape=(2,), dtype=float32)
# Iteration  203000  complete.
#
# tf.Tensor([74.91087 74.91135], shape=(2,), dtype=float32)
# Iteration  204000  complete.
#
# tf.Tensor([75.588455 75.588936], shape=(2,), dtype=float32)
# Iteration  205000  complete.
#
# tf.Tensor([75.80177 75.80227], shape=(2,), dtype=float32)
# Iteration  206000  complete.
#
# tf.Tensor([75.63421  75.634674], shape=(2,), dtype=float32)
# Iteration  207000  complete.
#
# tf.Tensor([75.36547 75.36593], shape=(2,), dtype=float32)
# Iteration  208000  complete.
#
# tf.Tensor([74.967316 74.96787 ], shape=(2,), dtype=float32)
# Iteration  209000  complete.
#
# tf.Tensor([76.49534 76.49589], shape=(2,), dtype=float32)
# Iteration  210000  complete.
#
# tf.Tensor([78.3443  78.34481], shape=(2,), dtype=float32)
# Iteration  211000  complete.
#
# tf.Tensor([78.96463 78.96512], shape=(2,), dtype=float32)
# Iteration  212000  complete.
#
# tf.Tensor([79.15429 79.15475], shape=(2,), dtype=float32)
# Iteration  213000  complete.
#
# tf.Tensor([79.627266 79.627655], shape=(2,), dtype=float32)
# Iteration  214000  complete.
#
# tf.Tensor([80.46552 80.46596], shape=(2,), dtype=float32)
# Iteration  215000  complete.
#
# tf.Tensor([80.59468 80.59508], shape=(2,), dtype=float32)
# Iteration  216000  complete.
#
# tf.Tensor([80.501   80.50141], shape=(2,), dtype=float32)
# Iteration  217000  complete.
#
# tf.Tensor([80.46638 80.46682], shape=(2,), dtype=float32)
# Iteration  218000  complete.
#
# tf.Tensor([81.38193 81.38241], shape=(2,), dtype=float32)
# Iteration  219000  complete.
#
# tf.Tensor([83.48054 83.48091], shape=(2,), dtype=float32)
# Iteration  220000  complete.
#
# tf.Tensor([84.7582  84.75851], shape=(2,), dtype=float32)
# Iteration  221000  complete.
#
# tf.Tensor([84.58739  84.587616], shape=(2,), dtype=float32)
# Iteration  222000  complete.
#
# tf.Tensor([84.150986 84.15127 ], shape=(2,), dtype=float32)
# Iteration  223000  complete.
#
# tf.Tensor([83.61025  83.610565], shape=(2,), dtype=float32)
# Iteration  224000  complete.
#
# tf.Tensor([82.755585 82.75588 ], shape=(2,), dtype=float32)
# Iteration  225000  complete.
#
# tf.Tensor([81.814545 81.81487 ], shape=(2,), dtype=float32)
# Iteration  226000  complete.
#
# tf.Tensor([80.79362 80.79397], shape=(2,), dtype=float32)
# Iteration  227000  complete.
#
# tf.Tensor([80.1502  80.15058], shape=(2,), dtype=float32)
# Iteration  228000  complete.
#
# tf.Tensor([79.29069  79.291084], shape=(2,), dtype=float32)
# Iteration  229000  complete.
#
# tf.Tensor([79.32348  79.323875], shape=(2,), dtype=float32)
# Iteration  230000  complete.
#
# tf.Tensor([79.36314 79.36352], shape=(2,), dtype=float32)
# Iteration  231000  complete.
#
# tf.Tensor([79.5913  79.59171], shape=(2,), dtype=float32)
# Iteration  232000  complete.
#
# tf.Tensor([80.20004 80.20043], shape=(2,), dtype=float32)
# Iteration  233000  complete.
#
# tf.Tensor([80.96933 80.96974], shape=(2,), dtype=float32)
# Iteration  234000  complete.
#
# tf.Tensor([81.55049  81.550865], shape=(2,), dtype=float32)
# Iteration  235000  complete.
#
# tf.Tensor([82.46019 82.46057], shape=(2,), dtype=float32)
# Iteration  236000  complete.
#
# tf.Tensor([83.12448  83.124855], shape=(2,), dtype=float32)
# Iteration  237000  complete.
#
# tf.Tensor([83.84552  83.845924], shape=(2,), dtype=float32)
# Iteration  238000  complete.
#
# tf.Tensor([84.497536 84.49791 ], shape=(2,), dtype=float32)
# Iteration  239000  complete.
#
# tf.Tensor([85.11959 85.12005], shape=(2,), dtype=float32)
# Iteration  240000  complete.
#
# tf.Tensor([85.62173  85.622185], shape=(2,), dtype=float32)
# Iteration  241000  complete.
#
# tf.Tensor([86.17289 86.17335], shape=(2,), dtype=float32)
# Iteration  242000  complete.
#
# tf.Tensor([86.32161 86.32204], shape=(2,), dtype=float32)
# Iteration  243000  complete.
#
# tf.Tensor([85.9235  85.92394], shape=(2,), dtype=float32)
# Iteration  244000  complete.
#
# tf.Tensor([85.280045 85.28046 ], shape=(2,), dtype=float32)
# Iteration  245000  complete.
#
# tf.Tensor([87.141014 87.14145 ], shape=(2,), dtype=float32)
# Iteration  246000  complete.
#
# tf.Tensor([87.27321 87.27365], shape=(2,), dtype=float32)
# Iteration  247000  complete.
#
# tf.Tensor([87.54396  87.544395], shape=(2,), dtype=float32)
# Iteration  248000  complete.
#
# tf.Tensor([87.83938  87.839806], shape=(2,), dtype=float32)
# Iteration  249000  complete.
#
# tf.Tensor([87.91536 87.91583], shape=(2,), dtype=float32)
# Iteration  250000  complete.
#
# tf.Tensor([88.00362 88.0041 ], shape=(2,), dtype=float32)
# Iteration  251000  complete.
#
# tf.Tensor([87.875404 87.87584 ], shape=(2,), dtype=float32)
# Iteration  252000  complete.
#
# tf.Tensor([88.29931 88.29975], shape=(2,), dtype=float32)
# Iteration  253000  complete.
#
# tf.Tensor([89.97194 89.97242], shape=(2,), dtype=float32)
# Iteration  254000  complete.
#
# tf.Tensor([91.134674 91.13513 ], shape=(2,), dtype=float32)
# Iteration  255000  complete.
#
# tf.Tensor([91.91012  91.910576], shape=(2,), dtype=float32)
# Iteration  256000  complete.
#
# tf.Tensor([92.754005 92.75452 ], shape=(2,), dtype=float32)
# Iteration  257000  complete.
#
# tf.Tensor([93.903534 93.904   ], shape=(2,), dtype=float32)
# Iteration  258000  complete.
#
# tf.Tensor([94.8642   94.864685], shape=(2,), dtype=float32)
# Iteration  259000  complete.
#
# tf.Tensor([95.207375 95.20781 ], shape=(2,), dtype=float32)
# Iteration  260000  complete.
#
# tf.Tensor([94.77414  94.774506], shape=(2,), dtype=float32)
# Iteration  261000  complete.
#
# tf.Tensor([95.020134 95.02052 ], shape=(2,), dtype=float32)
# Iteration  262000  complete.
#
# tf.Tensor([97.70045  97.700775], shape=(2,), dtype=float32)
# Iteration  263000  complete.
#
# tf.Tensor([99.11179 99.11214], shape=(2,), dtype=float32)
# Iteration  264000  complete.
#
# tf.Tensor([99.81831 99.81863], shape=(2,), dtype=float32)
# Iteration  265000  complete.
#
# tf.Tensor([100.52932  100.529625], shape=(2,), dtype=float32)
# tf.Tensor(100.52932, shape=(), dtype=float32)
